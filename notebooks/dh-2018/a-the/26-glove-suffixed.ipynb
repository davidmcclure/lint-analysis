# %%
from gensim.models import KeyedVectors

# %%
model = KeyedVectors.load_word2vec_format('../../data/glove-a-the/combined.w2v.txt')

# %%
model.similar_by_vector(model['a_BEG'] - model['the_BEG'], 100)
# Out:
# [('a_BEG', 0.7438544034957886),
#  ('a_END', 0.71929931640625),
#  ('—a', 0.5340713262557983),
#  ('а', 0.43273022770881653),
#  ('nice', 0.3978336453437805),
#  ('sort', 0.3969985246658325),
#  ('á', 0.371050626039505),
#  ('another', 0.35875770449638367),
#  ('trifle', 0.3445095121860504),
#  ('decent', 0.3398856520652771),
#  ('remarkably', 0.3274300694465637),
#  ('withal', 0.31288546323776245),
#  ('handsome', 0.3066962957382202),
#  ('lifetime', 0.29918187856674194),
#  ('smart', 0.2986288070678711),
#  ('λ', 0.29770368337631226),
#  ('jerk', 0.29110822081565857),
#  ('fit', 0.28901946544647217),
#  ('clever', 0.28748756647109985),
#  ('coward', 0.28689438104629517),
#  ('liar', 0.286637544631958),
#  ('chuckle', 0.2849156856536865),
#  ('shy', 0.2842930257320404),
#  ('queer', 0.28408050537109375),
#  ('surprisingly', 0.28004589676856995),
#  ('politician', 0.27979201078414917),
#  ('short', 0.27376875281333923),
#  ('single', 0.27311787009239197),
# ...

# %%
model.similar_by_vector(model['a_END'] - model['the_END'], 100)
# Out:
# [('a_END', 0.7318763732910156),
#  ('a_BEG', 0.7153317928314209),
#  ('—a', 0.5153780579566956),
#  ('а', 0.42791953682899475),
#  ('sort', 0.4154096245765686),
#  ('nice', 0.38658440113067627),
#  ('á', 0.3705874979496002),
#  ('another', 0.36284729838371277),
#  ('trifle', 0.3604564070701599),
#  ('chuckle', 0.3258814215660095),
#  ('decent', 0.3247441053390503),
#  ('queer', 0.30320078134536743),
#  ('λ', 0.2970728278160095),
#  ('smart', 0.2962861657142639),
#  ('lifetime', 0.2949830889701843),
#  ('liar', 0.2939475476741791),
#  ('coward', 0.29262828826904297),
#  ('gasp', 0.288604736328125),
#  ('remarkably', 0.2877840995788574),
#  ('politician', 0.2866690158843994),
#  ('shy', 0.28583094477653503),
#  ('jerk', 0.2853372395038605),
#  ('single', 0.2828299403190613),
#  ('short', 0.28012311458587646),
#  ('grunt', 0.2794370651245117),
#  ('clever', 0.2776747941970825),
#  ('husky', 0.2766813039779663),
#  ('withal', 0.27602818608283997),
#  ('fit', 0.27443796396255493),
# ...

# %%
model.similar_by_vector(model['the_BEG'] - model['a_BEG'], 100)
# Out:
# [('the_BEG', 0.43097978830337524),
#  ('the_END', 0.4239797592163086),
#  ('respective', 0.3261767327785492),
#  ('thè', 0.32277584075927734),
#  ('thé', 0.3211190700531006),
#  ('glories', 0.307015061378479),
#  ('crowds', 0.3006976544857025),
#  ('ignoring', 0.29073816537857056),
#  ('thereof', 0.29005804657936096),
#  ('tho', 0.28624650835990906),
#  ('surrounding', 0.28304213285446167),
#  ('their', 0.2822619676589966),
#  ('inmates', 0.2763657569885254),
#  ('eastern', 0.27582848072052),
#  ('sides', 0.27473121881484985),
#  ('all', 0.27130642533302307),
#  ('farthest', 0.2676006853580475),
#  ('fairest', 0.2616088092327118),
#  ('spaniards', 0.26015374064445496),
#  ('outer', 0.2595180869102478),
#  ('tlie', 0.2552088499069214),
#  ('saints', 0.2547873258590698),
#  ('deepest', 0.2529654800891876),
#  ('windows', 0.25263071060180664),
#  ('noblest', 0.2526194751262665),
#  ('crowding', 0.25257599353790283),
#  ('scanning', 0.251020610332489),
#  ('mists', 0.2503919005393982),
# ...

# %%
model.similar_by_vector(model['the_END'] - model['a_END'], 100)
# Out:
# [('the_END', 0.4565892517566681),
#  ('the_BEG', 0.4196549654006958),
#  ('thè', 0.33413565158843994),
#  ('thé', 0.3215491771697998),
#  ('tho', 0.3007112741470337),
#  ('respective', 0.300470232963562),
#  ('glories', 0.2991928160190582),
#  ('surrounding', 0.28928911685943604),
#  ('crowds', 0.2819580137729645),
#  ('ignoring', 0.2792704105377197),
#  ('thereof', 0.2779397666454315),
#  ('noblest', 0.2765693962574005),
#  ('fairest', 0.2764362692832947),
#  ('eastern', 0.265159547328949),
#  ('sides', 0.2597861588001251),
#  ('regardless', 0.25954750180244446),
#  ('spaniards', 0.25835829973220825),
#  ('tlie', 0.2542863190174103),
#  ('crowding', 0.2538180947303772),
#  ('rear', 0.25232595205307007),
#  ('mists', 0.25179052352905273),
#  ('saints', 0.2508004903793335),
#  ('outer', 0.25069093704223633),
#  ('scanning', 0.25062811374664307),
#  ('inmates', 0.2501717209815979),
#  ('windows', 0.24984684586524963),
#  ('farthest', 0.24965712428092957),
# ...

# %%
model.similar_by_vector(model['a_BEG'] - model['a_END'], 100)
# Out:
# [('aristocratic', 0.3650146722793579),
#  ('style', 0.34913188219070435),
#  ('athletic', 0.34619033336639404),
#  ('bred', 0.3311885595321655),
#  ('finely', 0.32969409227371216),
#  ('tanned', 0.3295672535896301),
#  ('13', 0.32793670892715454),
#  ('12', 0.3277595639228821),
#  ('shaggy', 0.3230748176574707),
#  ('masculine', 0.3215758204460144),
#  ('sturdy', 0.3193827271461487),
#  ('tall', 0.3186674118041992),
#  ('architecture', 0.31640878319740295),
#  ('type', 0.3160797357559204),
#  ('complexion', 0.30816712975502014),
#  ('consisted', 0.30596601963043213),
#  ('picturesque', 0.29914993047714233),
#  ('blonde', 0.2957615852355957),
#  ('attractive', 0.29535749554634094),
#  ('cultivated', 0.2937512695789337),
#  ('section', 0.29366135597229004),
#  ('typical', 0.29345229268074036),
#  ('wavy', 0.2925378382205963),
#  ('trim', 0.292520672082901),
#  ('fashioned', 0.29149824380874634),
#  ('well-', 0.2905445098876953),
#  ('quaint', 0.29014670848846436),
# ...

# %%
model.similar_by_vector(model['a_END'] - model['a_BEG'], 100)
# Out:
# [('dying', 0.40422704815864563),
#  ('joy', 0.3904210329055786),
#  ('agony', 0.38496965169906616),
#  ('anguish', 0.3656236529350281),
#  ('confession', 0.36441606283187866),
#  ('a_END', 0.353424608707428),
#  ('joyful', 0.35324206948280334),
#  ('terrible', 0.34270763397216797),
#  ('death', 0.338522732257843),
#  ('hope', 0.335896372795105),
#  ('remorse', 0.33561256527900696),
#  ('forgiveness', 0.3323248624801636),
#  ('triumph', 0.31868600845336914),
#  ('triumphant', 0.3177725672721863),
#  ('release', 0.31496134400367737),
#  ('resurrection', 0.31306761503219604),
#  ('dreadful', 0.3072526454925537),
#  ('message', 0.30670875310897827),
#  ('pain', 0.3061067461967468),
#  ('happiness', 0.3056892454624176),
#  ('dead', 0.30497801303863525),
#  ('benediction', 0.3018363416194916),
#  ('blessing', 0.30043986439704895),
#  ('the_END', 0.29927581548690796),
#  ('mercy', 0.29899755120277405),
#  ('despair', 0.29856550693511963),
#  ('guilty', 0.2978338599205017),
# ...

# %%
model.similar_by_vector((model['a_BEG'] - model['the_BEG']) - (model['a_END'] - model['the_END']), 100)
# Out:
# [('smashed', 0.2786158323287964),
#  ('groom', 0.25971442461013794),
#  ('trigger', 0.2595992684364319),
#  ('barrel', 0.24843282997608185),
#  ('stalwart', 0.24613988399505615),
#  ('the_END', 0.23814459145069122),
#  ('examined', 0.23704485595226288),
#  ('lock', 0.23498085141181946),
#  ('revolver', 0.23298758268356323),
#  ('bridegroom', 0.23212666809558868),
#  ('butt', 0.2213829904794693),
#  ('casket', 0.22110168635845184),
#  ('shaven', 0.22024662792682648),
#  ('manly', 0.21808484196662903),
#  ('yanked', 0.21416792273521423),
#  ('skeleton', 0.21227966248989105),
#  ('gun', 0.2120651751756668),
#  ('profile', 0.2114378809928894),
#  ('manhood', 0.21038362383842468),
#  ('cabinet', 0.20973898470401764),
#  ('traits', 0.20852182805538177),
#  ('crew', 0.2071963995695114),
#  ('deceased', 0.20667320489883423),
#  ('latch', 0.20580624043941498),
#  ('loosened', 0.20500215888023376),
#  ('ian', 0.2049262523651123),
#  ('wrenched', 0.20412211120128632),
# ...

# %%
model.similar_by_vector((model['a_END'] - model['the_END']) - (model['a_BEG'] - model['the_BEG']), 100)
# Out:
# [('dread', 0.28623488545417786),
#  ('aloud', 0.26469671726226807),
#  ('excitement', 0.2642594575881958),
#  ('fear', 0.25733405351638794),
#  ('whisper', 0.2566453516483307),
#  ('expectation', 0.2520773112773895),
#  ('apprehension', 0.24859358370304108),
#  ('suspense', 0.24795053899288177),
#  ('feverish', 0.2422708421945572),
#  ('a_END', 0.2419576197862625),
#  ('murmur', 0.24121436476707458),
#  ('nameless', 0.2388174831867218),
#  ('wonder', 0.23524978756904602),
#  ('moan', 0.23353591561317444),
#  ('chuckle', 0.232266366481781),
#  ('breathless', 0.2316385805606842),
#  ('joy', 0.23054823279380798),
#  ('uneasy', 0.22984391450881958),
#  ('sometimes', 0.22772714495658875),
#  ('intensity', 0.22772137820720673),
#  ('laugh', 0.22630906105041504),
#  ('ecstasy', 0.22616121172904968),
#  ('blinking', 0.2247452437877655),
#  ('thrill', 0.22189012169837952),
#  ('terror', 0.21992099285125732),
#  ('cry', 0.21972356736660004),
#  ('suppressed', 0.21867217123508453),
# ...

# %%
model.similar_by_vector((model['the_BEG'] - model['a_BEG']) - (model['the_END'] - model['a_END']), 100)
# Out:
# [('dread', 0.28623488545417786),
#  ('aloud', 0.26469671726226807),
#  ('excitement', 0.2642594575881958),
#  ('fear', 0.25733405351638794),
#  ('whisper', 0.2566453516483307),
#  ('expectation', 0.2520773112773895),
#  ('apprehension', 0.24859358370304108),
#  ('suspense', 0.24795053899288177),
#  ('feverish', 0.2422708421945572),
#  ('a_END', 0.2419576197862625),
#  ('murmur', 0.24121436476707458),
#  ('nameless', 0.2388174831867218),
#  ('wonder', 0.23524978756904602),
#  ('moan', 0.23353591561317444),
#  ('chuckle', 0.232266366481781),
#  ('breathless', 0.2316385805606842),
#  ('joy', 0.23054823279380798),
#  ('uneasy', 0.22984391450881958),
#  ('sometimes', 0.22772714495658875),
#  ('intensity', 0.22772137820720673),
#  ('laugh', 0.22630906105041504),
#  ('ecstasy', 0.22616121172904968),
#  ('blinking', 0.2247452437877655),
#  ('thrill', 0.22189012169837952),
#  ('terror', 0.21992099285125732),
#  ('cry', 0.21972356736660004),
#  ('suppressed', 0.21867217123508453),
# ...

# %%
model.similar_by_vector((model['the_END'] - model['a_END']) - (model['the_BEG'] - model['a_BEG']), 100)
# Out:
# [('smashed', 0.2786158323287964),
#  ('groom', 0.25971442461013794),
#  ('trigger', 0.2595992684364319),
#  ('barrel', 0.24843282997608185),
#  ('stalwart', 0.24613988399505615),
#  ('the_END', 0.23814459145069122),
#  ('examined', 0.23704485595226288),
#  ('lock', 0.23498085141181946),
#  ('revolver', 0.23298758268356323),
#  ('bridegroom', 0.23212666809558868),
#  ('butt', 0.2213829904794693),
#  ('casket', 0.22110168635845184),
#  ('shaven', 0.22024662792682648),
#  ('manly', 0.21808484196662903),
#  ('yanked', 0.21416792273521423),
#  ('skeleton', 0.21227966248989105),
#  ('gun', 0.2120651751756668),
#  ('profile', 0.2114378809928894),
#  ('manhood', 0.21038362383842468),
#  ('cabinet', 0.20973898470401764),
#  ('traits', 0.20852182805538177),
#  ('crew', 0.2071963995695114),
#  ('deceased', 0.20667320489883423),
#  ('latch', 0.20580624043941498),
#  ('loosened', 0.20500215888023376),
#  ('ian', 0.2049262523651123),
#  ('wrenched', 0.20412211120128632),
# ...
