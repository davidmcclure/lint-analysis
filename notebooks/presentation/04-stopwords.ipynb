# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline
mpl.style.use('bmh')

# %%
from numpy.random import multinomial

def sample_series(series, n=1000):
    return multinomial(series.sum(), series/series.sum(), n)

# %%
import numpy as np

from lint_analysis.bin_counts.models import BinCount

def plot_sampled_series(token, w=5, h=5):
    
    series = BinCount.token_series(token)
    
    expected = series.sum() / len(series)
    samples = sample_series(np.full(len(series), expected))
    
    avg_std = samples.std(1).mean()

    plt.figure(figsize=(w,h))
    
    plt.plot([0, 100], [expected, expected], c='orange', lw=0.5)

    plt.fill_between(
        range(101),
        expected + 2*avg_std,
        expected - 2*avg_std,
        color='black',
        alpha=0.1,
    )
    
    print(token)
    
    plt.title(token)
    plt.plot(series)
    plt.show()

# %%
plot_sampled_series('a')
plot_sampled_series('an')
plot_sampled_series('the')
# Out:
# a
# an
# the

# %%
plot_sampled_series('i', 2, 2)
plot_sampled_series('me', 2, 2)
plot_sampled_series('my', 2, 2)
# Out:
# i
# me
# my

# %%
plot_sampled_series('you', 2, 2)
plot_sampled_series('your', 2, 2)
# Out:
# you
# your

# %%
plot_sampled_series('he', 2, 2)
plot_sampled_series('him', 2, 2)
plot_sampled_series('his', 2, 2)
# Out:
# he
# him
# his

# %%
plot_sampled_series('she', 2, 2)
plot_sampled_series('her', 2, 2)
# Out:
# she
# her

# %%
plot_sampled_series('it')
plot_sampled_series('its')
# Out:
# it
# its

# %%
plot_sampled_series('we')
plot_sampled_series('us')
plot_sampled_series('our')
# Out:
# we
# us
# our

# %%
plot_sampled_series('be')
plot_sampled_series('am')
plot_sampled_series('is')
plot_sampled_series('are')
plot_sampled_series('was')
plot_sampled_series('were')
# Out:
# be
# am
# is
# are
# was
# were

# %%
plot_sampled_series('and')
plot_sampled_series('or')
plot_sampled_series('but')
# Out:
# and
# or
# but
