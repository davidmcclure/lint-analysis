# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline
mpl.style.use('bmh')

# %%
import numpy as np

import numpy.polynomial.polynomial as poly

from lint_analysis.bin_counts.models import BinCount

def plot_time_slices(token, y1=1840, y2=2000, w=20, rel=False):
    
    fig = plt.figure(figsize=(8, 8))
    ax = fig.add_subplot(111)
    
    cm = plt.get_cmap('plasma')
    
    years = range(y1, y2, w)
    
    colors = [
        cm(1.*i/len(years))
        for i in range(len(years))
    ]
    
    ax.set_color_cycle(colors)
    
    lines = []
    for y in years:
        
        # Plot the raw series.
        Y = BinCount.token_series(token, year1=y, year2=y+w)
        
        if rel:
            Y /= Y.sum()
            
        line, = ax.plot(Y, label=y)
        lines.append(line)
        
    plt.legend(
        handles=lines,
        bbox_to_anchor=(1.03, 1),
        loc=2,
        borderaxespad=0,
    )
        
    plt.title('"{}"'.format(token))
    plt.xlabel('Narrative time')
    plt.ylabel('Frequency')
    plt.show()

# %%
plot_time_slices('a')

# %%
plot_time_slices('a', rel=True)

# %%
plot_time_slices('marriage', rel=True)
