# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %matplotlib inline
mpl.style.use('bmh')

# %%
import numpy as np

# %%
from lint_analysis.bin_counts import cache

# %%
tokens = cache.token_counts(10000)

# %%
import re

from collections import OrderedDict

tokens = OrderedDict([
    (t, c) for t, c in tokens.items()
    if not re.match('^[0-9ivx.]+$', t)
])

# %%
data = []

for i, (token, count) in enumerate(tokens.items()):
    
    series = cache.token_series(token)
    exp_var = series.sum() * (1/100) * (1 - 1/100)
    
    data.append((count, series.var(), exp_var))
    
    if i % 1000 == 0: print(i)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000

# %%
import pandas as pd

df = pd.DataFrame(
    data,
    columns=('count', 'var', 'exp'),
    index=tokens.keys(),
)

# %%
import math

df['score'] = df.index.map(
    lambda t: df.loc[t]['var'] / df.loc[t]['exp']
)

# %%
top = df.sort_values('score', ascending=False).head(1000)

# %%
stopwords = top.sort_values('count', ascending=False).head(100)

# %%
stopwords.sort_values('score', ascending=False)
# Out:
#              count           var           exp        score
# ”         34933931  3.538836e+08  3.458459e+05  1023.240594
# you       20487595  1.984495e+08  2.028272e+05   978.416720
# a         44510387  3.708402e+08  4.406528e+05   841.569945
# of        50833243  4.126081e+08  5.032491e+05   819.888376
# the      111130017  8.759340e+08  1.100187e+06   796.168191
# ?         12766593  6.427682e+07  1.263893e+05   508.562307
# “         16921467  8.312866e+07  1.675225e+05   496.223808
# !          8067238  3.005259e+07  7.986566e+04   376.289268
# me         8542994  3.137667e+07  8.457564e+04   370.989478
# said       9326563  3.369125e+07  9.233297e+04   364.888653
# him       10323010  3.218044e+07  1.021978e+05   314.883920
# she       18306874  5.272078e+07  1.812381e+05   290.892435
# he        29859434  7.843062e+07  2.956084e+05   265.319324
# "          7698196  1.848088e+07  7.621214e+04   242.492611
# to        53624686  1.234725e+08  5.308844e+05   232.578860
# will       4290751  9.428596e+06  4.247843e+04   221.961947
# do         4976691  9.678962e+06  4.926924e+04   196.450396
# what       6170396  1.093636e+07  6.108692e+04   179.029434
# and       60309506  1.064227e+08  5.970641e+05   178.243281
# have       9362264  1.480190e+07  9.268641e+04   159.698649
# ,        147372390  2.190785e+08  1.458987e+06   150.157986
# now        4053836  5.663927e+06  4.013298e+04   141.129014
# that      24142406  3.340845e+07  2.390098e+05   139.778583
# it        23079990  3.162860e+07  2.284919e+05   138.423301
# not       11619960  1.556188e+07  1.150376e+05   135.276504
# know       3726770  4.990013e+06  3.689502e+04   135.248946
# we         5404398  7.174039e+06  5.350354e+04   134.085311
# your       4319424  5.683540e+06  4.276230e+04   132.910065
# in        30801843  4.013366e+07  3.049382e+05   131.612405
# an         5331677  6.833163e+06  5.278360e+04   129.456169
# ...            ...           ...           ...          ...
# any        2594544  1.163161e+06  2.568599e+04    45.283888
# thought    2234532  9.926071e+05  2.212187e+04    44.869953
# how        2554249  1.120586e+06  2.528707e+04    44.314601
# :          2684080  1.106827e+06  2.657239e+04    41.653267
# but       12255858  4.657215e+06  1.213330e+05    38.383748
# eyes       2424917  9.123946e+05  2.400668e+04    38.005865
# one        6618153  2.366318e+06  6.551971e+04    36.116116
# much       2203505  7.845405e+05  2.181470e+04    35.963846
# were       7082228  2.273907e+06  7.011406e+04    32.431548
# they       7976757  2.508368e+06  7.896989e+04    31.763600
# man        3646426  1.107278e+06  3.609962e+04    30.672848
# so         6691874  1.991656e+06  6.624955e+04    30.062939
# two        2296052  6.829262e+05  2.273091e+04    30.043938
# are        4436202  1.310646e+06  4.391840e+04    29.842753
# been       5349956  1.496869e+06  5.296456e+04    28.261716
# here       2623423  7.293430e+05  2.597189e+04    28.082016
# as        14628930  4.049411e+06  1.448264e+05    27.960447
# than       2822138  7.669977e+05  2.793917e+04    27.452418
# them       4960092  1.313384e+06  4.910491e+04    26.746482
# out        5806306  1.507995e+06  5.748243e+04    26.234013
# no         5126807  1.327501e+06  5.075539e+04    26.154883
# who        4526179  1.054405e+06  4.480917e+04    23.531009
# this       7621092  1.758255e+06  7.544881e+04    23.303947
# on        12056245  2.538661e+06  1.193568e+05    21.269508
# upon       2507899  4.581721e+05  2.482820e+04    18.453697
# never      2523764  4.268518e+05  2.498526e+04    17.084144
# there      6111906  1.001302e+06  6.050787e+04    16.548292
# just       2710304  4.376243e+05  2.683201e+04    16.309785
# ;          9843196  1.501284e+06  9.744764e+04    15.406056
# ¬          4917045  6.714390e+05  4.867875e+04    13.793268
#
# [100 rows x 4 columns]
